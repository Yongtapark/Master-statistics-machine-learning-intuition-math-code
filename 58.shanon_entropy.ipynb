# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
## discrete entropy

# generate data
N = 1000
numbers = np.ceil(8*np.random.rand(N)**2)
#numbers[numbers==7]=4
plt.plot(numbers,'o')

# %%
# get counts and probabilities
#u = [1,2,3,4,5,6,7,8]#np.unique(numbers)
u = np.unique(numbers)

probs = np.zeros(len(u))

for ui in range(len(u)):
    probs[ui] = sum(numbers==u[ui]) / N

# compute entropy
entropee = -sum(probs*np.log2(probs+np.finfo(float).eps))
print(np.finfo(float).eps)
# plot
plt.bar(u,probs)
plt.title('Entropy = %g'%entropee)
plt.xlabel('Data value')
plt.ylabel('Probability')
plt.show()
# Out:
# 2.220446049250313e-16

# %%
## for random variables

# create Borwnian noise
N = 1123
brownnoise = np.cumsum(np.random.randn(N))
print(np.random.randn(N))

fig,ax = plt.subplots(2,1, figsize=(4,6))
ax[0].plot(brownnoise)
ax[0].set_xlabel('Data index')
ax[0].set_ylabel('Data value')
ax[0].set_title('Brownian noise')

ax[1].hist(brownnoise/sum(brownnoise),30)
ax[1].set_xlabel('Data value')
ax[1].set_ylabel('Probability')
plt.show()
# Out:
# [ 0.49833487 -0.22841858  0.14123872 ... -0.68687735 -0.70030452
#   0.10184385]

# %%
### now compute entropy
# number of bins
nbins = 50

# bin the data and convert to probability
nPerBin,bins = np.histogram(brownnoise,nbins) #nPerBin = 각 bin에 속하는 데이터 포인트의 개수 / bins = 히스토그램의 경계값
probs = nPerBin / sum(nPerBin)

# compute entropy
entro = -sum(probs*np.log2(probs+np.finfo(float).eps))

print('Entropy = %g'%entro)
print(nPerBin)
# Out:
# Entropy = 5.38198
# [ 4  1 11 21 43 59 33 41 55 56 35 24 15  6 10  6  6 17 20 10 17 26 26 30
#  41 42 40 50 24 16 20 23 15 15 13 17 17 20 14 13 14 19 12 16 12 17 25 26
#  20 10]
